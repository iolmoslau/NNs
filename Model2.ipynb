# %%
import numpy as np
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import ConcatDataset, random_split, DataLoader
from torch.utils.data import DataLoader, TensorDataset
import torchvision
import torchvision.transforms as transforms

# %run CIFAR10_project.ipynb

# %% [markdown]
# Define Model Architecture

# %%
#Model 2 will have each hidden layer with width = 1405, 2 layers and use ReLu activaiton

shallow_wide_model_config = {
    "input_len": 3*32*32,
    "layer_widths": [1405,1405],
    "output_len": 10,
    "activation": "relu",
}

shallow_wide_model=mult_layer_percep(**shallow_wide_model_config)

# %% [markdown]
# Set up Training

# %%
loss_fn = nn.CrossEntropyLoss() #using cross entropy for classification task
optimizer = optim.Adam(shallow_wide_model.parameters(), lr=1e-3) 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
shallow_wide_model = shallow_wide_model.to(device)

# %% [markdown]
# Train and save best model losses/accs

# %%
train_losses_1,train_accs_1,val_losses_1,val_accs_1 = train_for_n_epochs(25,shallow_wide_model,train_loader,val_loader,loss_fn,optimizer,device)

torch.save( { "train_losses": train_losses_1, 
              "train_accs": train_accs_1, 
              "val_losses": val_losses_1, 
              "val_accs": val_accs_1, }, 
            "train_losses_model2.pt", )

# %% [markdown]
# Test and save model outputs and test loss

# %%
y_true, y_pred ,test_loss= predict_all(shallow_wide_model, test_loader,loss_fn, device)


torch.save(
    {
        "y_true": y_true.cpu(),
        "y_pred": y_pred.cpu(),
        "test_loss": float(test_loss),
    },
    "test_loss_and_output_model2.pt"
)
